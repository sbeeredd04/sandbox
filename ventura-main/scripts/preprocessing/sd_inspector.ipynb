# %%
import torch
from diffusers import DiffusionPipeline
from attention_map_diffusers import (
    attn_maps,
    init_pipeline,
    save_attention_maps
)


pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16,
)
pipe = pipe.to("cuda")

##### 1. Replace modules and Register hook #####
pipe = init_pipeline(pipe)
################################################

prompts = [
    # "A photo of a puppy wearing a hat.",
    "Caution tape blocking a sidewalk",
]

images = pipe(
    prompts,
    num_inference_steps=15,
).images

for batch, image in enumerate(images):
    image.save(f'{batch}-sd2-1.png')

##### 2. Process and Save attention map #####
save_attention_maps(attn_maps, pipe.tokenizer, prompts, base_dir='attn_maps-sd2-1', unconditional=True)
#############################################
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusion3Pipeline
from attention_map_diffusers import (
    attn_maps,
    init_pipeline,
    save_attention_maps
)

pipe = StableDiffusion3Pipeline.from_pretrained(
    "stabilityai/stable-diffusion-3.5-medium",
    torch_dtype=torch.bfloat16
)
pipe = pipe.to("cuda")

##### 1. Replace modules and Register hook #####
pipe = init_pipeline(pipe)
################################################

# recommend not using batch operations for sd3, as cpu memory could be exceeded.
prompts = [
    # "A photo of a puppy wearing a hat.",
    "A capybara holding a sign that reads Hello World.",
]

images = pipe(
    prompts,
    num_inference_steps=15,
    guidance_scale=4.5,
).images

for batch, image in enumerate(images):
    image.save(f'{batch}-sd3-5.png')

##### 2. Process and Save attention map #####
save_attention_maps(attn_maps, pipe.tokenizer, prompts, base_dir='attn_maps-sd3-5', unconditional=True)
#############################################
# Out:
# [2025-07-29 19:44:11,021] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: warning: librt.so.1, needed by /usr/local/cuda-12.8/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: warning: libpthread.so.0, needed by /usr/local/cuda-12.8/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: warning: libstdc++.so.6, needed by /usr/local/cuda-12.8/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: warning: libm.so.6, needed by /usr/local/cuda-12.8/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::runtime_error::~runtime_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__gxx_personality_v0@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream::tellp()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::chrono::_V2::steady_clock::now()@GLIBCXX_3.4.19'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_M_replace_aux(unsigned long, unsigned long, unsigned long, char)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for bool@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_logic_error(char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::logic_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::locale::~locale()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::string const&, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_end_catch@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::logic_error::~logic_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__si_class_type_info@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::_M_cache_locale(std::locale const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `operator new[](unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_M_leak_hard()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >::basic_streambuf(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> > const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::append(char const*, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::string const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned short@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::resize(unsigned long, char)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for char const*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ctype<char>::_M_widen_init() const@GLIBCXX_3.4.11'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_invalid_argument(char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::locale::operator=(std::locale const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ios<wchar_t, std::char_traits<wchar_t> >::_M_cache_locale(std::locale const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_free_exception@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::condition_variable::notify_one()@GLIBCXX_3.4.11'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ios_base::Init::~Init()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::~basic_string()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_pure_virtual@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream::flush()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__class_type_info@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_rethrow@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_fstream<char, std::char_traits<char> >::~basic_fstream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::compare(char const*) const@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_ostringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::locale::locale()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::chrono::_V2::system_clock::now()@GLIBCXX_3.4.19'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Hash_bytes(void const*, unsigned long, unsigned long)@CXXABI_1.3.5'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long long>(long long)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for char*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__detail::_Prime_rehash_policy::_M_need_rehash(unsigned long, unsigned long, unsigned long) const@GLIBCXX_3.4.18'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::out_of_range@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long>(unsigned long)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ios_base::~ios_base()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::range_error::~range_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::~__basic_file()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_guard_acquire@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<bool>(bool)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::overflow_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::range_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ios<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_filebuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `operator delete[](void*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(unsigned long, char, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_transfer(std::__detail::_List_node_base*, std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::replace(unsigned long, unsigned long, char const*, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for std::exception@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_Rep::_M_destroy(std::allocator<wchar_t> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::istream& std::istream::_M_extract<double>(double&)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::basic_ifstream(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::append(std::string const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `operator new(unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_istringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned int@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::append(char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::domain_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::find(char, unsigned long) const@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream::put(char)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for int@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_bad_alloc()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_thread_atexit@CXXABI_1.3.7'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned int*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::~basic_ifstream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ios_base::Init::Init()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::condition_variable::condition_variable()@GLIBCXX_3.4.11'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::basic_filebuf()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::domain_error::~domain_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::cerr@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::find(char const*, unsigned long, unsigned long) const@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::allocator<char> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::str() const@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::invalid_argument@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for void*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::assign(std::string const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_ostringstream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_rebalance_for_erase(std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_hook(std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_unhook()@GLIBCXX_3.4.15'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ostringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::_M_sync(char*, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_iostream<char, std::char_traits<char> >::~basic_iostream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::locale::locale(std::locale const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_istringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `log2f@GLIBC_2.2.5'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::exception::~exception()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_create(unsigned long, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::is_open() const@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_istringstream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::swap(std::string&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_streambuf<char, std::char_traits<char> >::basic_streambuf(std::basic_streambuf<char, std::char_traits<char> > const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::init(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_bad_cast()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::clear(std::_Ios_Iostate)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >::operator=(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> > const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for long*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `operator delete(void*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(int)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_empty_rep_storage@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_Rep::_M_destroy(std::allocator<char> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_iostream<wchar_t, std::char_traits<wchar_t> >::~basic_iostream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::runtime_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_insert_and_rebalance(bool, std::_Rb_tree_node_base*, std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_stringstream()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `VTT for std::basic_stringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long>(long)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::istream::get()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long long@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::operator<< <std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::out_of_range::~out_of_range()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::length_error::~length_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::__ostream_insert<char, std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*, long)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::invalid_argument::~invalid_argument()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::swap(std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::cout@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long long>(unsigned long long)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<void const*>(void const*)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::underflow_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_streambuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for std::out_of_range@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_allocate_exception@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_ios<wchar_t, std::char_traits<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for void const*@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ios<wchar_t, std::char_traits<wchar_t> >::init(std::basic_streambuf<wchar_t, std::char_traits<wchar_t> >*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::reserve(unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_begin_catch@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for long@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_Rep::_S_empty_rep_storage@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::_M_leak()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::open(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >::_M_sync(wchar_t*, unsigned long, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::istream::getline(char*, long, char)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_istream<char, std::char_traits<char> >& std::getline<char, std::char_traits<char>, std::allocator<char> >(std::basic_istream<char, std::char_traits<char> >&, std::basic_string<char, std::char_traits<char>, std::allocator<char> >&, char)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringstream<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::condition_variable::~condition_variable()@GLIBCXX_3.4.11'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringbuf<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> >@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::insert(unsigned long, char const*, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::string::assign(char const*, unsigned long)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for unsigned char@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ios_base::ios_base()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_out_of_range(char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::overflow_error::~overflow_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_length_error(char const*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::__throw_system_error(int)@GLIBCXX_3.4.11'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ofstream<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<double>(double)@GLIBCXX_3.4.9'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_streambuf<char, std::char_traits<char> >::operator=(std::basic_streambuf<char, std::char_traits<char> > const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `typeinfo for long long@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(char const*, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_guard_release@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `__cxa_throw@CXXABI_1.3'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::underflow_error::~underflow_error()@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `vtable for std::length_error@GLIBCXX_3.4'
# /home/ubuntu/miniconda3/envs/spinflow/compiler_compat/ld: /usr/local/cuda-12.8/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::~basic_filebuf()@GLIBCXX_3.4'
# collect2: error: ld returned 1 exit status
# [2025-07-29 19:44:12,422] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# model_index.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# text_encoder_3/model-00001-of-00002.safe(…):   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/740 [00:00<?, ?B/s]
# text_encoder_3/model-00002-of-00002.safe(…):   0%|          | 0.00/4.53G [00:00<?, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/247M [00:00<?, ?B/s]
# text_encoder_2/model.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/19.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/576 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/856 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# tokenizer_3/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/20.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/524 [00:00<?, ?B/s]
# transformer/diffusion_pytorch_model.safe(…):   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/809 [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
